# %%
#Import scikit-learn dataset library
from sklearn import datasets

# %%
import pandas as pd
PollPlants = pd.read_csv ('D:/BiCIKL_UseCase/CPC-Pollinator common name/PollPlantsGBIF2.csv')
print('PollPlants data set has got {} rows and {} columns'.format(PollPlants.shape[0],PollPlants.shape[1]))
PollPlants.head()
# Out:
# PollPlants data set has got 79990 rows and 21 columns
#   pollinator_scientific                   pollinator_taxonKey  \
# 0      Bombus sylvicola  https://www.gbif.org/species/1340525
# 1         Bombus mixtus  https://www.gbif.org/species/1340485
# 2         Hyles lineata  https://www.gbif.org/species/1862841
# 3   Pontia occidentalis  https://www.gbif.org/species/5137791
# 4          Hada sutrina  https://www.gbif.org/species/1761076
#
#              pollinator_scientificName pollinator_kingdom pollinator_phylum  \
# 0         Bombus sylvicola Kirby, 1837           Animalia        Arthropoda
# 1          Bombus mixtus Cresson, 1879           Animalia        Arthropoda
# 2        Hyles lineata Fabricius, 1775           Animalia        Arthropoda
# 3  Pontia occidentalis (Reakirt, 1866)           Animalia        Arthropoda
# 4             Hada sutrina Grote, 1881           Animalia        Arthropoda
#
#   pollinator_order pollinator_family pollinator_genus   pollinator_species  \
# ...

# %%
PollPlants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79990 entries, 0 to 79989
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pollinator_scientific      79990 non-null  object
#  1   pollinator_taxonKey        79990 non-null  object
#  2   pollinator_scientificName  79990 non-null  object
#  3   pollinator_kingdom         79990 non-null  object
#  4   pollinator_phylum          79990 non-null  object
#  5   pollinator_order           79990 non-null  object
#  6   pollinator_family          79980 non-null  object
#  7   pollinator_genus           79767 non-null  object
#  8   pollinator_species         78094 non-null  object
#  9   pollinator_country         79974 non-null  object
#  10  plant_scientific           79990 non-null  object
#  11  plant_taxonKey             79990 non-null  object
#  12  plant_scientificName       79990 non-null  object
# ...

# %%
PollPlants_drop = PollPlants.drop(columns =['pollinator_species', 'plant_species']) # 2 columns will not be used to train the algorithm, so we drop them

# %%
PollPlants_drop.info()  # some of the columns contain nulls (how to handle them?)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79990 entries, 0 to 79989
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pollinator_scientific      79990 non-null  object
#  1   pollinator_taxonKey        79990 non-null  object
#  2   pollinator_scientificName  79990 non-null  object
#  3   pollinator_kingdom         79990 non-null  object
#  4   pollinator_phylum          79990 non-null  object
#  5   pollinator_order           79990 non-null  object
#  6   pollinator_family          79980 non-null  object
#  7   pollinator_genus           79767 non-null  object
#  8   pollinator_country         79974 non-null  object
#  9   plant_scientific           79990 non-null  object
#  10  plant_taxonKey             79990 non-null  object
#  11  plant_scientificName       79990 non-null  object
#  12  plant_kingdom              79990 non-null  object
# ...

# %%
PollPlants_drop2 = PollPlants_drop.dropna()
PollPlants_drop2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79512 entries, 0 to 79989
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pollinator_scientific      79512 non-null  object
#  1   pollinator_taxonKey        79512 non-null  object
#  2   pollinator_scientificName  79512 non-null  object
#  3   pollinator_kingdom         79512 non-null  object
#  4   pollinator_phylum          79512 non-null  object
#  5   pollinator_order           79512 non-null  object
#  6   pollinator_family          79512 non-null  object
#  7   pollinator_genus           79512 non-null  object
#  8   pollinator_country         79512 non-null  object
#  9   plant_scientific           79512 non-null  object
#  10  plant_taxonKey             79512 non-null  object
#  11  plant_scientificName       79512 non-null  object
#  12  plant_kingdom              79512 non-null  object
# ...

# %%
PollPlants_drop2.head()
# Out:
#   pollinator_scientific                   pollinator_taxonKey  \
# 0      Bombus sylvicola  https://www.gbif.org/species/1340525
# 1         Bombus mixtus  https://www.gbif.org/species/1340485
# 2         Hyles lineata  https://www.gbif.org/species/1862841
# 3   Pontia occidentalis  https://www.gbif.org/species/5137791
# 4          Hada sutrina  https://www.gbif.org/species/1761076
#
#              pollinator_scientificName pollinator_kingdom pollinator_phylum  \
# 0         Bombus sylvicola Kirby, 1837           Animalia        Arthropoda
# 1          Bombus mixtus Cresson, 1879           Animalia        Arthropoda
# 2        Hyles lineata Fabricius, 1775           Animalia        Arthropoda
# 3  Pontia occidentalis (Reakirt, 1866)           Animalia        Arthropoda
# 4             Hada sutrina Grote, 1881           Animalia        Arthropoda
#
#   pollinator_order pollinator_family pollinator_genus  \
# 0      Hymenoptera            Apidae           Bombus
# ...

# %%
# Separate the columns into dependent and independent variables (or features and labels). Then split those variables into 
# a training and test set.

# Import train_test_split function
from sklearn.model_selection import train_test_split

X = PollPlants_drop2[['pollinator_scientific', 'pollinator_taxonKey', 'pollinator_scientificName', 'pollinator_kingdom', 'pollinator_phylum', 'pollinator_order', 'pollinator_family', 'pollinator_genus', 'pollinator_country', 'plant_scientific', 'plant_taxonKey', 'plant_scientificName', 'plant_kingdom', 'plant_phylum', 'plant_order', 'plant_family', 'plant_genus', 'plant_country']]  # Features
y = PollPlants_drop2['class']  # Labels

# %%
X.dtypes
# Out:
# pollinator_scientific        object
# pollinator_taxonKey          object
# pollinator_scientificName    object
# pollinator_kingdom           object
# pollinator_phylum            object
# pollinator_order             object
# pollinator_family            object
# pollinator_genus             object
# pollinator_country           object
# plant_scientific             object
# plant_taxonKey               object
# plant_scientificName         object
# plant_kingdom                object
# plant_phylum                 object
# plant_order                  object
# plant_family                 object
# plant_genus                  object
# plant_country                object
# dtype: object

# %%
X.head()
# Out:
#   pollinator_scientific                   pollinator_taxonKey  \
# 0      Bombus sylvicola  https://www.gbif.org/species/1340525
# 1         Bombus mixtus  https://www.gbif.org/species/1340485
# 2         Hyles lineata  https://www.gbif.org/species/1862841
# 3   Pontia occidentalis  https://www.gbif.org/species/5137791
# 4          Hada sutrina  https://www.gbif.org/species/1761076
#
#              pollinator_scientificName pollinator_kingdom pollinator_phylum  \
# 0         Bombus sylvicola Kirby, 1837           Animalia        Arthropoda
# 1          Bombus mixtus Cresson, 1879           Animalia        Arthropoda
# 2        Hyles lineata Fabricius, 1775           Animalia        Arthropoda
# 3  Pontia occidentalis (Reakirt, 1866)           Animalia        Arthropoda
# 4             Hada sutrina Grote, 1881           Animalia        Arthropoda
#
#   pollinator_order pollinator_family pollinator_genus  \
# 0      Hymenoptera            Apidae           Bombus
# ...

# %%
x = isinstance(X, pd.DataFrame)

print(x)
# Out:
# True

# %%
X["pollinator_scientific"] = X["pollinator_scientific"].apply(lambda val: sorted(list(X["pollinator_scientific"].unique())).index(val))
# Out:
# <ipython-input-13-dc75f8d841ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["pollinator_scientific"] = X["pollinator_scientific"].apply(lambda val: sorted(list(X["pollinator_scientific"].unique())).index(val))

# %%
X.head()
# Out:
#    pollinator_scientific                   pollinator_taxonKey  \
# 0                    440  https://www.gbif.org/species/1340525
# 1                    430  https://www.gbif.org/species/1340485
# 2                   1194  https://www.gbif.org/species/1862841
# 3                   1962  https://www.gbif.org/species/5137791
# 4                   1093  https://www.gbif.org/species/1761076
#
#              pollinator_scientificName pollinator_kingdom pollinator_phylum  \
# 0         Bombus sylvicola Kirby, 1837           Animalia        Arthropoda
# 1          Bombus mixtus Cresson, 1879           Animalia        Arthropoda
# 2        Hyles lineata Fabricius, 1775           Animalia        Arthropoda
# 3  Pontia occidentalis (Reakirt, 1866)           Animalia        Arthropoda
# 4             Hada sutrina Grote, 1881           Animalia        Arthropoda
#
#   pollinator_order pollinator_family pollinator_genus  \
# 0      Hymenoptera            Apidae           Bombus
# ...

# %%
X["pollinator_taxonKey"] = X["pollinator_taxonKey"].apply(lambda val: sorted(list(X["pollinator_taxonKey"].unique())).index(val))
# Out:
# <ipython-input-16-8a839b894c19>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["pollinator_taxonKey"] = X["pollinator_taxonKey"].apply(lambda val: sorted(list(X["pollinator_taxonKey"].unique())).index(val))

# %%
X.head()
# Out:
#    pollinator_scientific  pollinator_taxonKey  \
# 0                    440                  229
# 1                    430                  221
# 2                   1194                  745
# 3                   1962                 1897
# 4                   1093                  726
#
#              pollinator_scientificName pollinator_kingdom pollinator_phylum  \
# 0         Bombus sylvicola Kirby, 1837           Animalia        Arthropoda
# 1          Bombus mixtus Cresson, 1879           Animalia        Arthropoda
# 2        Hyles lineata Fabricius, 1775           Animalia        Arthropoda
# 3  Pontia occidentalis (Reakirt, 1866)           Animalia        Arthropoda
# 4             Hada sutrina Grote, 1881           Animalia        Arthropoda
#
#   pollinator_order pollinator_family pollinator_genus  \
# 0      Hymenoptera            Apidae           Bombus
# 1      Hymenoptera            Apidae           Bombus
# 2      Lepidoptera        Sphingidae            Hyles
# ...

# %%
X["pollinator_scientificName"] = X["pollinator_scientificName"].apply(lambda val: sorted(list(X["pollinator_scientificName"].unique())).index(val))
# Out:
# <ipython-input-18-34f6cc7b2d7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["pollinator_scientificName"] = X["pollinator_scientificName"].apply(lambda val: sorted(list(X["pollinator_scientificName"].unique())).index(val))

# %%
X.head()
# Out:
#    pollinator_scientific  pollinator_taxonKey  pollinator_scientificName  \
# 0                    440                  229                        433
# 1                    430                  221                        423
# 2                   1194                  745                       1189
# 3                   1962                 1897                       1954
# 4                   1093                  726                       1088
#
#   pollinator_kingdom pollinator_phylum pollinator_order pollinator_family  \
# 0           Animalia        Arthropoda      Hymenoptera            Apidae
# 1           Animalia        Arthropoda      Hymenoptera            Apidae
# 2           Animalia        Arthropoda      Lepidoptera        Sphingidae
# 3           Animalia        Arthropoda      Lepidoptera          Pieridae
# 4           Animalia        Arthropoda      Lepidoptera         Noctuidae
#
#   pollinator_genus        pollinator_country   plant_scientific  \
# ...

# %%
X["pollinator_kingdom"] = X["pollinator_kingdom"].apply(lambda val: sorted(list(X["pollinator_kingdom"].unique())).index(val))
# Out:
# <ipython-input-20-53f211e0c69b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["pollinator_kingdom"] = X["pollinator_kingdom"].apply(lambda val: sorted(list(X["pollinator_kingdom"].unique())).index(val))

# %%
X.head()
# Out:
#    pollinator_scientific  pollinator_taxonKey  pollinator_scientificName  \
# 0                    440                  229                        433
# 1                    430                  221                        423
# 2                   1194                  745                       1189
# 3                   1962                 1897                       1954
# 4                   1093                  726                       1088
#
#    pollinator_kingdom  pollinator_phylum pollinator_order pollinator_family  \
# 0                   0                  0      Hymenoptera            Apidae
# 1                   0                  0      Hymenoptera            Apidae
# 2                   0                  0      Lepidoptera        Sphingidae
# 3                   0                  0      Lepidoptera          Pieridae
# 4                   0                  0      Lepidoptera         Noctuidae
#
#   pollinator_genus        pollinator_country   plant_scientific  \
# ...

# %%
import matplotlib.pyplot as plt

x=y.value_counts()
plt.bar(x.index,x)
plt.gca().set_xticks([0,1])
plt.title('distribution of target variable')
plt.show()

# %%
from sklearn.feature_extraction import FeatureHasher

X_PollPlants_drop2_hash = X.copy()
for c in X.columns:
    X_PollPlants_drop2_hash[c] = X[c].astype('str')      
hashing = FeatureHasher(input_type = 'string')
PollPlants_drop2 = hashing.transform(X_PollPlants_drop2_hash.values)

# %%
print('PollPlants_drop2 data set has got {} rows and {} columns'.format(PollPlants_drop2.shape[0],PollPlants_drop2.shape[1]))
# Out:
# PollPlants_drop2 data set has got 79512 rows and 1048576 columns

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

def logistic(X,y):
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)
    lr=LogisticRegression()
    lr.fit(X_train,y_train)
    y_pre=lr.predict(X_test)
    print('Accuracy : ',accuracy_score(y_test,y_pre))

# %%
logistic(PollPlants_drop2,y) # low accuracy score??
# Out:
# Accuracy :  0.38998931019304534
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-4cdf4346fa15> in <module>
#       6
#       7 #Train the model using the training sets y_pred=clf.predict(X_test)
# ----> 8 clf.fit(X_train,y_train)
#       9
#      10 y_pred=clf.predict(X_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
# ...

# %%
PollPlants.fillna(value = -999,
          inplace = True)

# %%
PollPlants.info() #no nulls anymore
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79990 entries, 0 to 79989
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pollinator_scientific      79990 non-null  object
#  1   pollinator_taxonKey        79990 non-null  object
#  2   pollinator_scientificName  79990 non-null  object
#  3   pollinator_kingdom         79990 non-null  object
#  4   pollinator_phylum          79990 non-null  object
#  5   pollinator_order           79990 non-null  object
#  6   pollinator_family          79990 non-null  object
#  7   pollinator_genus           79990 non-null  object
#  8   pollinator_species         79990 non-null  object
#  9   pollinator_country         79990 non-null  object
#  10  plant_scientific           79990 non-null  object
#  11  plant_taxonKey             79990 non-null  object
#  12  plant_scientificName       79990 non-null  object
# ...

# %%
PollPlants.head()
# Out:
#   pollinator_scientific                   pollinator_taxonKey  \
# 0      Bombus sylvicola  https://www.gbif.org/species/1340525
# 1         Bombus mixtus  https://www.gbif.org/species/1340485
# 2         Hyles lineata  https://www.gbif.org/species/1862841
# 3   Pontia occidentalis  https://www.gbif.org/species/5137791
# 4          Hada sutrina  https://www.gbif.org/species/1761076
#
#              pollinator_scientificName pollinator_kingdom pollinator_phylum  \
# 0         Bombus sylvicola Kirby, 1837           Animalia        Arthropoda
# 1          Bombus mixtus Cresson, 1879           Animalia        Arthropoda
# 2        Hyles lineata Fabricius, 1775           Animalia        Arthropoda
# 3  Pontia occidentalis (Reakirt, 1866)           Animalia        Arthropoda
# 4             Hada sutrina Grote, 1881           Animalia        Arthropoda
#
#   pollinator_order pollinator_family pollinator_genus   pollinator_species  \
# ...
